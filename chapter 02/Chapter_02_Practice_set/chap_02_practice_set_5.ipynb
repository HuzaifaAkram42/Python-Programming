# %% [markdown]
# ## String Example Programs

# %% [markdown]
# #### 1. Find the length of a given string without using the len() function

# %%
s = input("Enter a sentence ")
counter = 0
for i in s:
    counter+=1
print(counter)
# Out:
# Enter a sentence  Pakistan Zindabad
# 17

# %% [markdown]
# #### 2. Extract username from a given email.
#  - Eg if the email is nitish24singh@gmail.com
#  - then the username should be nitish24singh

# %%
email = input("Enter your Email ")

username = email[:email.find("@")]
print(username)
# Out:
# Enter your Email  huzaifaniazi654@gmail.com
# huzaifaniazi654

# %% [markdown]
# #### 3. Count the frequency of a particular character in a provided string.
# Eg 'hello how are you' is the string, the frequency of h in this string is 2.

# %%
s = input("Enter a sentence ")
term = input("What would you like to search for ")
counter = 0
for i in s:
    if i == term:
        counter+=1
print('Frequency',counter)
# Out:
# Enter a sentence  huzaifa niazi
# What would you like to search for  i
# Frequency 3

# %% [markdown]
# #### 4. Write a program which can remove a particular character from a string.

# %%
s = input("Enter a sentence ")
term = input("What would you like to remove for ")
result = ""

for i in s:
    if i != term:
        result = result + i
print(result)
# Out:
# Enter a sentence  huzaifa niazi
# What would you like to remove for  i
# huzafa naz

# %% [markdown]
# #### 5. Write a program that can check whether a given string is palindrome or not.
# abba
# malayalam

# %%
s = input("Enter a string ")
flag = True
for i in range(1,len(s)//2):
    if s[i] != s[len(s)-i-1]:
        print("not a Palindrome")
        flag = False
        break
if flag:
    print("its a Palindrome")
# Out:
# Enter a string  malayalam
# its a Palindrome

# %% [markdown]
# #### 6. Write a program to count the number of words in a string without split()

# %%
s = input("Enter a string ")
temp = ''
L = []
for i in s:
    if i != " ":
        temp = temp + i
    else:
        L.append(temp)
        temp = ""
L.append(temp)
print(L)
# Out:
# Enter a string  hello how are you
# ['hello', 'how', 'are', 'you']

# %% [markdown]
# #### 7. Write a python program to convert a string to title case without using the title()

# %%
s = input("Enter a string ")
L = []
for i in s.split():
    L.append((i[0].upper()+i[1:].lower()))
print(" ".join(L))
# Out:
# Enter a string  hellO how aRE yoU
# Hello How Are You

# %% [markdown]
# #### 8. Write a program that can convert an integer to string.

# %%
number = int(input("Enter a number "))
digit = "0123456789"
result = ''
while number != 0:
    result = digit[number % 10] + result
    number = number // 10
result
# Out:
# Enter a number  6548
# '6548'
